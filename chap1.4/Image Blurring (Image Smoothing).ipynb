# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('LetterR_opencv.png')
kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv2.imread('sp1.jpg')
s = 7
blur = cv2.GaussianBlur(img,(s,s),0)
median = cv2.medianBlur(img,s)
plt.figure(figsize=(32,24))
plt.subplot(121),plt.imshow(img),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Medianed')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv2.imread('sp2.png')
s = 7
blur = cv2.GaussianBlur(img,(s,s),0)
median = cv2.medianBlur(img,s)
plt.figure(figsize=(26,24))
plt.subplot(121),plt.imshow(img),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Medianed')
plt.xticks([]), plt.yticks([])
plt.show()
